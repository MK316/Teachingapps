# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Teachingapps/blob/main/TeacherTalk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 💦 4. My teaching transcript (in English)

# %%
#@markdown Step #1:🚩 install {gTTS} packages and import:
# %%capture

# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio
import pandas as pd
from google.colab import files
     
#@markdown Defining **tts(text)**
def tts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say, lang = "en", tld="com", slow = False)
  gtts_object.save("myscript.wav")
  return Audio("myscript.wav")

# %% [markdown]
# 📗 [1] English speech
#
# **Note:** Any punctuation (comma, period) are mostly for written language, not usually for speech. If you use a comman, it'll makes a short pause, which may sound unnatural in some cases. So, consider not using a comma unless you really need a pause between clauses.

# %% [markdown]
# [1] Copy and paste your script in the pop-up box
#
# [sample text](https://en.wikipedia.org/wiki/Digital_literacy)
# [Or use chatGPT](https://openai.com/blog/chatgpt/):
# [Ask] Make a 100 words length of greeting talk for middle school English class, whose topic is learning reading a short story with 2 group activities.

# %%
#@markdown ✒️ Get ready your text to paste:
script = input("Paste your script here. (Then, ENTER key)")
print("="*50)
print(script)
print("="*50)
tts(script)
# Out:
# Paste your script here. (Then, ENTER key)Hello class!  Welcome to our lesson on reading short stories. I hope you're all excited to dive into some great literature today.  Before we begin, I want to quickly go over our plan for the class. We will start by reading a short story together as a class, and then we will break into two groups for some interactive activities.  The first group activity will involve analyzing the characters and plot of the story. We will discuss the motivations and actions of the characters, and how they contribute to the overall plot.  The second group activity will focus on the theme of the story. We will consider the message or lesson that the author is trying to convey through the story, and how it relates to our own lives.  I'm looking forward to a great lesson and some great discussions with all of you. Let's get started!
# ...

# %% [markdown]
# Note: When finding vocabulary in your transcript, consder the following.
#
# * 5th graders - 1st year of middle school (possibly)
# * 6th graders - Middle school student level
